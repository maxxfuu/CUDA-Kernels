# %%
"""
MNIST Data Preprocessing Script
Downloads MNIST dataset and saves it in binary format for efficient loading
"""

import os
import shutil

import numpy as np
from torchvision import datasets, transforms

# Directory to save processed data
save_dir = "data"
os.makedirs(save_dir, exist_ok=True)

# Transform to convert PIL images to tensors
transform = transforms.Compose([transforms.ToTensor()])

# Download MNIST training dataset
mnist_train = datasets.MNIST(
    root="./data", train=True, download=True, transform=transform
)

# Download MNIST test dataset
mnist_test = datasets.MNIST(
    root="./data", train=False, download=True, transform=transform
)

# Extract and normalize image data (28x28 pixels flattened to 784)
# Normalize pixel values from [0, 255] to [0.0, 1.0]
X_train = mnist_train.data.numpy().reshape(-1, 28 * 28).astype(np.float32) / 255.0
y_train = mnist_train.targets.numpy().astype(np.int32)
X_test = mnist_test.data.numpy().reshape(-1, 28 * 28).astype(np.float32) / 255.0
y_test = mnist_test.targets.numpy().astype(np.int32)

# Save data and labels to binary files for fast loading
X_train.tofile(os.path.join(save_dir, "X_train.bin"))
y_train.tofile(os.path.join(save_dir, "y_train.bin"))
X_test.tofile(os.path.join(save_dir, "X_test.bin"))
y_test.tofile(os.path.join(save_dir, "y_test.bin"))

# Write metadata file with dataset information
with open(os.path.join(save_dir, "metadata.txt"), "w") as f:
    f.write(f"Training samples: {X_train.shape[0]}\n")
    f.write(f"Test samples: {X_test.shape[0]}\n")
    f.write(f"Input dimensions: {X_train.shape[1]}\n")
    f.write(f"Number of classes: {len(np.unique(y_train))}\n")

# Clean up temporary directories created by torchvision
if os.path.exists("mnist_data"):
    shutil.rmtree("mnist_data")
    print("Removed mnist_data directory")

if os.path.exists(os.path.join(save_dir, "MNIST")):
    shutil.rmtree(os.path.join(save_dir, "MNIST"))
    print("Removed MNIST raw data directory")

print("MNIST dataset has been downloaded and saved in binary format in data/ directory.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 10
#       6 import os
#       7 import shutil
#       8
#       9 import numpy as np
# ---> 10 from torchvision import datasets, transforms
#      11
#      12 # Directory to save processed data
#      13 save_dir = "data"
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torchvision/__init__.py:8
#       5 # Don't re-order these, we need to load the _C extension (done when importing
#       6 # .extension) before entering _meta_registrations.
#       7 from . import extension  # usort:skip  # noqa: F401
# ----> 8 from torchvision import (
#       9     _autograd_registrations,
#      10     _meta_registrations,
#      11     datasets,
#      12     io,
#      13     models,
#      14     ops,
#      15     transforms,
#      16     utils,
#      17 )  # usort:skip
#      19 try:
#      20     from .version import __version__  # noqa: F401
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torchvision/models/__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torchvision/models/convnext.py:9
#       6 from torch import nn, Tensor
#       7 from torch.nn import functional as F
# ----> 9 from ..ops.misc import Conv2dNormActivation, Permute
#      10 from ..ops.stochastic_depth import StochasticDepth
#      11 from ..transforms._presets import ImageClassification
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torchvision/ops/__init__.py:23
#      21 from .giou_loss import generalized_box_iou_loss
#      22 from .misc import Conv2dNormActivation, Conv3dNormActivation, FrozenBatchNorm2d, MLP, Permute, SqueezeExcitation
# ---> 23 from .poolers import MultiScaleRoIAlign
#      24 from .ps_roi_align import ps_roi_align, PSRoIAlign
#      25 from .ps_roi_pool import ps_roi_pool, PSRoIPool
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torchvision/ops/poolers.py:10
#       7 from torchvision.ops.boxes import box_area
#       9 from ..utils import _log_api_usage_once
# ---> 10 from .roi_align import roi_align
#      13 # copying result_idx_in_level to a specific index in result[]
#      14 # is not supported by ONNX tracing yet.
#      15 # _onnx_merge_levels() is an implementation supported by ONNX
#      16 # that merges the levels to the right indices
#      17 @torch.jit.unused
#      18 def _onnx_merge_levels(levels: Tensor, unmerged_results: list[Tensor]) -> Tensor:
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torchvision/ops/roi_align.py:7
#       5 import torch.fx
#       6 from torch import nn, Tensor
# ----> 7 from torch._dynamo.utils import is_compile_supported
#       8 from torch.jit.annotations import BroadcastingList2
#       9 from torch.nn.modules.utils import _pair
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torch/_dynamo/__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)      8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import (
#      14     aot_compile,
#      15     bytecode_debugger,
#      16     config,
#      17     convert_frame,
#      18     eval_frame,
#      19     functional_export,
#      20     resume_execution,
#      21 )
#      22 from .backends.registry import list_backends, lookup_backend, register_backend
#      23 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torch/_dynamo/aot_compile.py:17
#      15 import torch
#      16 import torch.fx
# ---> 17 from torch._dynamo.convert_frame import GraphRuntimeEnv
#      18 from torch._dynamo.graph_utils import _graph_device_type
#      19 from torch._dynamo.package import SystemInfo
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:62
#      60 from torch._dynamo.callback import CallbackTrigger
#      61 from torch._dynamo.distributed import get_compile_pg
# ---> 62 from torch._dynamo.symbolic_convert import TensorifyState
#      63 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      64 from torch._logging import structured
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:62
#      59 from torch.fx.experimental.symbolic_shapes import guard_bool
#      60 from torch.utils._functools import cache_method
# ---> 62 from . import (
#      63     config,
#      64     exc,
#      65     graph_break_hints,
#      66     logging as torchdynamo_logging,
#      67     trace_rules,
#      68     variables,
#      69 )
#      70 from .bytecode_analysis import (
#      71     get_indexof,
#      72     JUMP_OPNAMES,
#      73     livevars_analysis,
#      74     propagate_line_nums,
#      75 )
#      76 from .bytecode_transformation import (
#      77     cleaned_instructions,
#      78     create_binary_slice,
#    (...)     92     unique_id,
#      93 )
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torch/_dynamo/trace_rules.py:45
#      42 from typing import Any
#      44 import torch
# ---> 45 import torch._inductor.test_operators
#      46 import torch.distributed
#      47 import torch.utils._content_store
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torch/_inductor/__init__.py:12
#       8 from typing import Any, IO, Literal, Optional, TYPE_CHECKING, Union
#      10 import torch.fx
# ---> 12 from .standalone_compile import CompiledArtifact, DynamicShapesType  # noqa: TC001
#      15 if TYPE_CHECKING:
#      16     from torch._inductor.utils import InputType
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torch/_inductor/standalone_compile.py:19
#      17 from torch._dynamo.aot_compile_types import BundledAOTAutogradSerializableCallable
#      18 from torch._dynamo.utils import dynamo_timed
# ---> 19 from torch._inductor.cpp_builder import normalize_path_separator
#      20 from torch._inductor.cudagraph_utils import BoxedDeviceIndex
#      21 from torch._inductor.runtime.cache_dir_utils import temporary_cache_dir
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torch/_inductor/cpp_builder.py:30
#      28 import torch
#      29 from torch._dynamo.utils import dynamo_timed
# ---> 30 from torch._inductor import config, exc
#      31 from torch._inductor.cpu_vec_isa import invalid_vec_isa, VecISA
#      32 from torch._inductor.runtime.runtime_utils import cache_dir
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torch/_inductor/config.py:1373
#    1369     return compile_threads
#    1372 # TODO: Set directly after internal rollout.
# -> 1373 compile_threads: int | None = None if is_fbcode() else decide_compile_threads()
#    1375 # Whether to quiesce the Triton-compile subprocess pool at the end of each compilation.
#    1376 quiesce_async_compile_pool: bool = Config(
#    1377     justknob="pytorch/inductor:quiesce_async_compile_pool",
#    1378     env_name_force="TORCHINDUCTOR_QUIESCE_ASYNC_COMPILE_POOL",
#    1379     default=True,
#    1380 )
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torch/_inductor/config.py:1364, in decide_compile_threads()
#    1362     log.info("compile_threads set to 1 in fbcode")
#    1363 else:
# -> 1364     cpu_count = torch._utils.cpu_count()
#    1365     assert cpu_count
#    1366     compile_threads = min(32, cpu_count)
#
# File ~/miniconda3/envs/gpt3/lib/python3.11/site-packages/torch/__init__.py:2963, in __getattr__(name)
#    2960     warnings.warn(f"'{name}' is deprecated, please do not call", stacklevel=2)
#    2961     return lambda *args: None
# -> 2963 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute '_utils'
